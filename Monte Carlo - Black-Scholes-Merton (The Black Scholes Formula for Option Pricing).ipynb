# %% [markdown]
# ## Monte Carlo - Black-Scholes-Merton

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
from scipy.stats import norm

data = pd.read_csv('/Users/arm2/Downloads/Python for Finance and Investment (Udemy)/MSFT_2000.csv', index_col = 'Date')

# %%
def d1(S, K, r, stdev, T):
    return (np.log(S / K) + (r + stdev ** 2 / 2) * T) / (stdev * np.sqrt(T))
 
def d2(S, K, r, stdev, T):
    return (np.log(S / K) + (r - stdev ** 2 / 2) * T) / (stdev * np.sqrt(T))

def BSM(S, K, r, stdev, T):
        return (S * norm.cdf(d1(S, K, r, stdev, T))) - (K * np.exp(-r * T) * norm.cdf(d2(S, K, r, stdev, T)))

# %%
#d1
#d2

from skimage import io
 
img = io.imread("Screenshot 2023-12-15 at 20.19.24.png")
io.imshow(img)

# %%
norm.cdf(0)
# Out:
# 0.5

# %%
norm.cdf(0.25)
# Out:
# 0.5987063256829237

# %%
norm.cdf(0.75)
# Out:
# 0.7733726476231317

# %%
norm.cdf(9)
# Out:
# 1.0

# %%
from skimage import io
 
img1 = io.imread("Screenshot 2023-12-15 at 20.25.08.png")
io.imshow(img1)

# %%
img2 = io.imread("Screenshot 2023-12-15 at 20.25.50.png")
io.imshow(img2)

# %%
img3 = io.imread("Screenshot 2023-12-15 at 20.26.07.png")
io.imshow(img3)

# %%
img4 = io.imread("Screenshot 2023-12-15 at 20.26.24.png")
io.imshow(img4)

# %%
log_returns = np.log(1 + data.pct_change())

# %%
log_returns.tail()
# Out:
#                 MSFT
# Date
# 12-10-2017  0.009118
# 13-10-2017  0.004786
# 16-10-2017  0.002063
# 17-10-2017 -0.000773
# 18-10-2017  0.000258

# %%
stdev = log_returns.std() * 250 ** 0.5
stdev
# Out:
# MSFT    0.306691
# dtype: float64

# %%
r = 0.025
K = 110.0
T = 1

# %%
S = data.iloc[-1]
S
# Out:
# MSFT    77.610001
# Name: 18-10-2017, dtype: float64

# %%
d1(S, K, r, stdev, T)
# Out:
# MSFT   -0.902389
# dtype: float64

# %%
d2(S, K, r, stdev, T)
# Out:
# MSFT   -1.20908
# dtype: float64

# %%
BSM(S, K, r, stdev, T)
# Out:
# MSFT    2.078609
# Name: 18-10-2017, dtype: float64
